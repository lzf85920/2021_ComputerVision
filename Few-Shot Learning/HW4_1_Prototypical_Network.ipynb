# %%
from google.colab import drive
drive._mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# !cp -r /content/drive/MyDrive/HW4/prototypical-network/test_testcase.py /content/test_testcase.py

# %%
# !unzip /content/drive/MyDrive/HW4/hw4_data.zip
# Out:
# 串流輸出內容已截斷至最後 5000 行。
#   inflating: hw4_data/mini/train/n0207436700000661.jpg
#   inflating: hw4_data/mini/train/n0461250400000869.jpg
#   inflating: hw4_data/mini/train/n0216545600000546.jpg
#   inflating: hw4_data/mini/train/n0451500300001128.jpg
#   inflating: hw4_data/mini/train/n0438903300000330.jpg
#   inflating: hw4_data/mini/train/n0388860500000891.jpg
#   inflating: hw4_data/mini/train/n0208986700000124.jpg
#   inflating: hw4_data/mini/train/n0427554800000800.jpg
#   inflating: hw4_data/mini/train/n0279516900000391.jpg
#   inflating: hw4_data/mini/train/n0385406500000270.jpg
#   inflating: hw4_data/mini/train/n0367648300001190.jpg
#   inflating: hw4_data/mini/train/n0304769000000851.jpg
#   inflating: hw4_data/mini/train/n0177008100000336.jpg
#   inflating: hw4_data/mini/train/n0268717200001040.jpg
#   inflating: hw4_data/mini/train/n0333714000000408.jpg
#   inflating: hw4_data/mini/train/n0210808900000686.jpg
#   inflating: hw4_data/mini/train/n1305456000000727.jpg
# ...

# %% [markdown]
# # 20way-1shot

# %%
# https://github.com/yinboc/prototypical-network-pytorch
# !python3 /content/prototypical-network/train.py --shot 1 --train-way 20 --save-path /content/drive/MyDrive/HW4/model
# Out:
# {'gpu': '0',
#  'max_epoch': 200,
#  'query': 15,
#  'save_epoch': 20,
#  'save_path': '/content/drive/MyDrive/HW4/model',
#  'shot': 1,
#  'test_way': 5,
#  'train_way': 20}
# using gpu: 0
# /content/drive/MyDrive/HW4/model exists, remove? ([y]/n)n
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# # 5way-1shot

# %%
# !python3 /content/prototypical-network/train.py --shot 1 --train-way 5 --save-path /content/drive/MyDrive/HW4/5w1s --max-epoch 100
# Out:
# {'gpu': '0',
#  'max_epoch': 100,
#  'query': 15,
#  'save_epoch': 20,
#  'save_path': '/content/drive/MyDrive/HW4/5w1s',
#  'shot': 1,
#  'test_way': 5,
#  'train_way': 5}
# using gpu: 0
# /content/drive/MyDrive/HW4/5w1s exists, remove? ([y]/n)n
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %%
# !python3 /content/prototypical-network/test.py --load /content/drive/MyDrive/HW4/5w1s/max-acc.pth --shot 1 --way 5
# Out:
# {'batch': 2000,
#  'gpu': '0',
#  'load': '/content/drive/MyDrive/HW4/5w1s/max-acc.pth',
#  'query': 30,
#  'shot': 1,
#  'way': 5}
# using gpu: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100% 2000/2000 [01:22<00:00, 24.23it/s]
# 0.40669000962376595

# %% [markdown]
# # 5way-5shot

# %%
# !python3 /content/prototypical-network/train.py --shot 5 --train-way 5 --save-path /content/drive/MyDrive/HW4/5w5s --max-epoch 100
# Out:
# {'gpu': '0',
#  'max_epoch': 100,
#  'query': 15,
#  'save_epoch': 20,
#  'save_path': '/content/drive/MyDrive/HW4/5w5s',
#  'shot': 5,
#  'test_way': 5,
#  'train_way': 5}
# using gpu: 0
# /content/drive/MyDrive/HW4/5w5s exists, remove? ([y]/n)n
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %%
# !python3 /content/prototypical-network/test.py --load /content/drive/MyDrive/HW4/5w5s/max-acc.pth --shot 5 --way 5
# Out:
# {'batch': 2000,
#  'gpu': '0',
#  'load': '/content/drive/MyDrive/HW4/5w5s/max-acc.pth',
#  'query': 30,
#  'shot': 5,
#  'way': 5}
# using gpu: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100% 2000/2000 [01:32<00:00, 21.59it/s]
# 0.6236000144481659

# %% [markdown]
# # 5way-10shot

# %%
# !python3 /content/prototypical-network/train.py --shot 10 --train-way 5 --save-path /content/drive/MyDrive/HW4/5w10s --max-epoch 100
# Out:
# {'gpu': '0',
#  'max_epoch': 100,
#  'query': 15,
#  'save_epoch': 20,
#  'save_path': '/content/drive/MyDrive/HW4/5w10s',
#  'shot': 10,
#  'test_way': 5,
#  'train_way': 5}
# using gpu: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %%
# !python3 /content/prototypical-network/test.py --load /content/drive/MyDrive/HW4/5w10s/max-acc.pth --shot 10 --way 5
# Out:
# {'batch': 2000,
#  'gpu': '0',
#  'load': '/content/drive/MyDrive/HW4/5w10s/max-acc.pth',
#  'query': 30,
#  'shot': 10,
#  'way': 5}
# using gpu: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# 100% 2000/2000 [01:45<00:00, 18.87it/s]
# 0.6900466823279857

# %% [markdown]
# # Evaluation

# %%
# !python3 /content/prototypical-network/test_testcase.py --load /content/drive/MyDrive/HW4/20w1s/max-acc.pth --test_data_dir /content/hw4_data/mini/val --test_csv /content/hw4_data/mini/val.csv --testcase_csv /content/hw4_data/mini/val_testcase.csv --output_csv /content/output.csv

# %%
# !sh /content/drive/MyDrive/HW4/hw4_p1.sh /content/hw4_data/mini/val.csv /content/hw4_data/mini/val /content/hw4_data/mini/val_testcase.csv /content/output.csv
# Out:
# --2022-01-01 17:39:12--  https://www.dropbox.com/s/r8o6pr8xus60vzz/max-acc.pth?dl=1
# Resolving www.dropbox.com (www.dropbox.com)... 162.125.5.18, 2620:100:601f:18::a27d:912
# Connecting to www.dropbox.com (www.dropbox.com)|162.125.5.18|:443... connected.
# HTTP request sent, awaiting response... 301 Moved Permanently
# Location: /s/dl/r8o6pr8xus60vzz/max-acc.pth [following]
# --2022-01-01 17:39:12--  https://www.dropbox.com/s/dl/r8o6pr8xus60vzz/max-acc.pth
# Reusing existing connection to www.dropbox.com:443.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ucdebd8f906ff23eb64115c6e889.dl.dropboxusercontent.com/cd/0/get/Bc8BsbUgKzVpaklVxb9UPj0WN1RwVNWquBYbBGE2v81Vg5wVd816vAQ_JT42DRNN_6OPtt1xuSK8VT4BzN0eDzKa4sdatoSdtcKt-m9lLom4cEnWRch78OeuUfooKVEx-rza6-zIHTZeg-_7-G2WWX_X/file?dl=1# [following]
# ...

# %%
# !python3 /content/drive/MyDrive/HW4/prototypical-network/eval.py /content/output.csv /content/hw4_data/mini/val_testcase_gt.csv
# Out:
# Accuracy: 46.34 +- 0.82 %

# %%
# !cp -r /content/prototypical-network /content/drive/MyDrive/HW4

# %% [markdown]
# # Different distance metrix

# %%
# cosin_similarity

# https://github.com/yinboc/prototypical-network-pytorch
# !python3 /content/prototypical-network/train.py --shot 1 --train-way 20 --dis_metrix 'cosin_similarity' --save-path /content/drive/MyDrive/HW4/20w1s_cos
# Out:
# {'dis_metrix': 'cosin_similarity',
#  'gpu': '0',
#  'max_epoch': 100,
#  'query': 15,
#  'save_epoch': 20,
#  'save_path': '/content/drive/MyDrive/HW4/20w1s_cos',
#  'shot': 1,
#  'test_way': 5,
#  'train_way': 20}
# using gpu: 0
# /content/drive/MyDrive/HW4/20w1s_cos exists, remove? ([y]/n)y
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %%
# cosin_similarity
try:
  os.system('rm -r /content/drive/MyDrive/HW4/5w1s_cos')
except:
  pass
# https://github.com/yinboc/prototypical-network-pytorch
# !python3 /content/prototypical-network/train.py --shot 1 --train-way 5 --dis_metrix 'cosin_similarity' --save-path /content/drive/MyDrive/HW4/5w1s_cos
# Out:
# {'dis_metrix': 'cosin_similarity',
#  'gpu': '0',
#  'max_epoch': 100,
#  'query': 15,
#  'save_epoch': 20,
#  'save_path': '/content/drive/MyDrive/HW4/5w1s_cos',
#  'shot': 1,
#  'test_way': 5,
#  'train_way': 5}
# using gpu: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %%
# parametric function
import os
try:
  os.system('rm -r /content/drive/MyDrive/HW4/5w1s_para')
except:
  pass

# https://github.com/yinboc/prototypical-network-pytorch
# !python3 /content/prototypical-network/train.py --shot 1 --train-way 5 --dis_metrix 'parametric' --save-path /content/drive/MyDrive/HW4/5w1s_para
# Out:
# {'dis_metrix': 'parametric',
#  'gpu': '0',
#  'max_epoch': 100,
#  'query': 15,
#  'save_epoch': 20,
#  'save_path': '/content/drive/MyDrive/HW4/5w1s_para',
#  'shot': 1,
#  'test_way': 5,
#  'train_way': 5}
# using gpu: 0
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:481: UserWarning: This DataLoader will create 8 worker processes in total. Our suggested max number of worker in current system is 4, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# ...

# %% [markdown]
# # Eavluation different distance metrix

# %%
# euclidean
# !python3 /content/prototypical-network/test_testcase.py --load /content/drive/MyDrive/HW4/5w1s/max-acc.pth --test_data_dir /content/hw4_data/mini/val --test_csv /content/hw4_data/mini/val.csv --testcase_csv /content/hw4_data/mini/val_testcase.csv --output_csv /content/output_5w1s.csv

# cosin similarity
# !python3 /content/prototypical-network/test_testcase.py --load /content/drive/MyDrive/HW4/5w1s_cos/max-acc.pth --dis_metrix 'cosin_similarity' --test_data_dir /content/hw4_data/mini/val --test_csv /content/hw4_data/mini/val.csv --testcase_csv /content/hw4_data/mini/val_testcase.csv --output_csv /content/output_5w1s_cos.csv

# parametric function
# !cp /content/drive/MyDrive/HW4/5w1s_para/max-acc-para.pth /content/max-acc_para.pth
# !python3 /content/prototypical-network/test_testcase.py --load /content/drive/MyDrive/HW4/5w1s_para/max-acc.pth --dis_metrix 'parametric' --test_data_dir /content/hw4_data/mini/val --test_csv /content/hw4_data/mini/val.csv --testcase_csv /content/hw4_data/mini/val_testcase.csv --output_csv /content/output_5w1s_para.csv

# %%
print('Euclidean')
# !python3 /content/prototypical-network/eval.py /content/output_5w1s.csv /content/hw4_data/mini/val_testcase_gt.csv
print('-------------------')

print('Cosin similarity')
# !python3 /content/prototypical-network/eval.py /content/output_5w1s_cos.csv /content/hw4_data/mini/val_testcase_gt.csv
print('-------------------')

print('Parametric function')
# !python3 /content/prototypical-network/eval.py /content/output_5w1s_para.csv /content/hw4_data/mini/val_testcase_gt.csv
print('-------------------')
# Out:
# Euclidean
# Accuracy: 40.77 +- 0.77 %
# -------------------
# Cosin similarity
# Accuracy: 24.77 +- 0.45 %
# -------------------
# Parametric function
# Accuracy: 20.14 +- 0.37 %
# -------------------
